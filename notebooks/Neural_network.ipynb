# %%
import sys
import os
sys.path.append(os.path.abspath(".."))
import numpy as np
import pandas as pd
import tensorflow as tf
from src.preprocessing import preprocessor, X, Y
from tensorflow import keras 
from keras import models, layers, optimizers
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import confusion_matrix 


# splitting input and output data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=42)

# additional preprocessing of input training data for a sequential artificial neural network model
preprocessor.fit(X_train)
X_train_preprocessed = preprocessor.transform(X_train)

input_dim = X_train_preprocessed.shape[1] 

# Label encoding
encoding = LabelEncoder()
y_train_encoded = encoding.fit_transform(y_train)
y_test_encoded = encoding.transform(y_test)

# amount of classes 
num_classes = len(np.unique(y_train_encoded))

# one-hot encoding
y_train_encoded = tf.keras.utils.to_categorical(y_train_encoded, num_classes=num_classes)
y_test_encoded = tf.keras.utils.to_categorical(y_test_encoded, num_classes=num_classes)

# additional preprocessing of input testing data for a sequential artificial neural network model
X_test_preprocessed = preprocessor.transform(X_test)

# learning rate configuration
optimizer = optimizers.Adam(learning_rate=0.001)

# architecture of a multilayer perceptron classifier
model = models.Sequential([
    layers.Input(shape=(input_dim,)),
    layers.Dense(20, activation="relu"), 
    layers.Dropout(0.3),
    layers.Dense(10, activation="relu"), 
    layers.Dropout(0.3),
    layers.Dense(num_classes, activation="softmax"),
])

# model compilation 
model.compile(loss="categorical_crossentropy", optimizer=optimizer, metrics=["accuracy"])

# structure of artificial neural network 
structure = model.summary()

# matrix of weights and biases
Matrix_W = model.get_weights()

# training a artificial neural network model
model.fit(X_train_preprocessed, y_train_encoded, epochs=50, batch_size=32, validation_split=0.2)

# model prediction 
y_pred = model.predict(X_test_preprocessed)

# selecting the index with the highest probability
y_test_labels = np.argmax(y_test_encoded, axis=1)
y_pred_selected = np.argmax(y_pred, axis=1)   

# evaluation of model fit using the accuracy metric
accuracy_values = accuracy_score (y_test_labels, y_pred_selected)

# evaluation of model fit using the precision metric
precision_values = precision_score (y_test_labels, y_pred_selected, average='macro')

# evaluation of model fit using the recall metric
recall_values = recall_score (y_test_labels, y_pred_selected, average = 'macro')

labels = np.arange(num_classes)

# evaluation of model fit using the confusion matrix 
confusionmatrix_values = confusion_matrix(y_test_labels, y_pred_selected, labels = labels)
# Out:
# C:\Users\kejdi\anaconda3\envs\models\lib\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\kejdi\anaconda3\envs\models\lib\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 20)                  │             400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 20)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │             210 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 10)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 3)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 643 (2.51 KB)
#  Trainable params: 643 (2.51 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.2788 - loss: 1.2174 - val_accuracy: 0.3167 - val_loss: 1.1418
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3043 - loss: 1.1730 - val_accuracy: 0.3667 - val_loss: 1.1274
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.2922 - loss: 1.1351 - val_accuracy: 0.4000 - val_loss: 1.1173
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3193 - loss: 1.2775 - val_accuracy: 0.4167 - val_loss: 1.1094
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3570 - loss: 1.2184 - val_accuracy: 0.4167 - val_loss: 1.1028
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3931 - loss: 1.1219 - val_accuracy: 0.4000 - val_loss: 1.0984
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3423 - loss: 1.2334 - val_accuracy: 0.4000 - val_loss: 1.0946
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4037 - loss: 1.1058 - val_accuracy: 0.3667 - val_loss: 1.0918
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3681 - loss: 1.0656 - val_accuracy: 0.4167 - val_loss: 1.0886
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4035 - loss: 1.1219 - val_accuracy: 0.4167 - val_loss: 1.0861
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3774 - loss: 1.1181 - val_accuracy: 0.4167 - val_loss: 1.0838
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3571 - loss: 1.1419 - val_accuracy: 0.4333 - val_loss: 1.0813
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4615 - loss: 1.1034 - val_accuracy: 0.4333 - val_loss: 1.0783
# Epoch 14/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.4062 - loss: 1.1574 - val_accuracy: 0.4333 - val_loss: 1.0763
# Epoch 15/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3716 - loss: 1.0829 - val_accuracy: 0.4500 - val_loss: 1.0742
# Epoch 16/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4273 - loss: 1.1549 - val_accuracy: 0.4500 - val_loss: 1.0718
# Epoch 17/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4696 - loss: 1.0615 - val_accuracy: 0.4833 - val_loss: 1.0700
# Epoch 18/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4521 - loss: 1.0734 - val_accuracy: 0.4833 - val_loss: 1.0679
# Epoch 19/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4195 - loss: 1.0871 - val_accuracy: 0.4833 - val_loss: 1.0668
# Epoch 20/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4528 - loss: 1.2125 - val_accuracy: 0.4833 - val_loss: 1.0655
# Epoch 21/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4314 - loss: 1.0555 - val_accuracy: 0.4833 - val_loss: 1.0644
# Epoch 22/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4477 - loss: 1.0781 - val_accuracy: 0.4833 - val_loss: 1.0626
# Epoch 23/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4585 - loss: 1.0866 - val_accuracy: 0.4833 - val_loss: 1.0615
# Epoch 24/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4090 - loss: 1.0582 - val_accuracy: 0.4833 - val_loss: 1.0599
# Epoch 25/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4332 - loss: 1.0766 - val_accuracy: 0.4833 - val_loss: 1.0577
# Epoch 26/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4929 - loss: 1.0615 - val_accuracy: 0.4833 - val_loss: 1.0549
# Epoch 27/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4568 - loss: 1.0661 - val_accuracy: 0.4833 - val_loss: 1.0528
# Epoch 28/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4376 - loss: 1.0440 - val_accuracy: 0.4833 - val_loss: 1.0514
# Epoch 29/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4327 - loss: 1.0236 - val_accuracy: 0.4833 - val_loss: 1.0496
# Epoch 30/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4222 - loss: 1.2010 - val_accuracy: 0.4833 - val_loss: 1.0482
# Epoch 31/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4758 - loss: 1.0416 - val_accuracy: 0.4833 - val_loss: 1.0469
# Epoch 32/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4892 - loss: 1.0318 - val_accuracy: 0.4833 - val_loss: 1.0451
# Epoch 33/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4457 - loss: 1.0391 - val_accuracy: 0.4833 - val_loss: 1.0424
# Epoch 34/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4224 - loss: 1.1076 - val_accuracy: 0.4833 - val_loss: 1.0405
# Epoch 35/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5161 - loss: 1.0255 - val_accuracy: 0.4833 - val_loss: 1.0393
# Epoch 36/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4662 - loss: 1.0444 - val_accuracy: 0.4833 - val_loss: 1.0394
# Epoch 37/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4486 - loss: 1.0237 - val_accuracy: 0.4833 - val_loss: 1.0395
# Epoch 38/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4648 - loss: 1.0293 - val_accuracy: 0.4833 - val_loss: 1.0394
# Epoch 39/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4682 - loss: 1.0463 - val_accuracy: 0.4833 - val_loss: 1.0391
# Epoch 40/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4508 - loss: 1.0277 - val_accuracy: 0.5167 - val_loss: 1.0386
# Epoch 41/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5500 - loss: 1.0004 - val_accuracy: 0.5167 - val_loss: 1.0367
# Epoch 42/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4435 - loss: 1.0384 - val_accuracy: 0.4833 - val_loss: 1.0361
# Epoch 43/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4580 - loss: 1.0165 - val_accuracy: 0.4833 - val_loss: 1.0353
# Epoch 44/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4820 - loss: 1.0187 - val_accuracy: 0.4833 - val_loss: 1.0360
# Epoch 45/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4482 - loss: 1.0384 - val_accuracy: 0.4833 - val_loss: 1.0353
# Epoch 46/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4425 - loss: 1.0371 - val_accuracy: 0.4833 - val_loss: 1.0353
# Epoch 47/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4272 - loss: 1.0379 - val_accuracy: 0.4667 - val_loss: 1.0338
# Epoch 48/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4101 - loss: 1.0357 - val_accuracy: 0.4667 - val_loss: 1.0308
# Epoch 49/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4519 - loss: 1.0311 - val_accuracy: 0.4667 - val_loss: 1.0294
# Epoch 50/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4798 - loss: 1.0264 - val_accuracy: 0.4667 - val_loss: 1.0281
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
